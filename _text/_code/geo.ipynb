# %%
# Geo coordinates

# %%
import pandas as pd
import ast

# Replace 'your_file.xlsx' with the path to your Excel file
df = pd.read_excel('princeton_postcard_metadata_withMessage.xlsx')
# Convert the 'ImagePaths' column to lists
df['ImagePaths'] = df['ImagePaths'].apply(ast.literal_eval)

# Now 'df' is a DataFrame containing your Excel data. You can view it with:
df.head()
# Out:
#                                             FilePath                 OBJID  \
# 0  /content/drive/My Drive/AC045/AC045_c0055/0001...  ark:/88435/3f4625544
# 1  /content/drive/My Drive/AC045/AC045_c0055/0004...  ark:/88435/sb3978362
# 2  /content/drive/My Drive/AC045/AC045_c0028/0001...  ark:/88435/h128nd82h
# 3  /content/drive/My Drive/AC045/AC045_c0069/0003...  ark:/88435/r781wg134
# 4  /content/drive/My Drive/AC045/AC045_c0069/0002...  ark:/88435/gx41mh96w
#
#                                     RecordIdentifier  \
# 0  http://diglib.princeton.edu/mdata/pudl0009/1/0...
# 1  http://diglib.princeton.edu/mdata/pudl0009/1/0...
# 2  http://diglib.princeton.edu/mdata/pudl0009/1/0...
# 3  http://diglib.princeton.edu/mdata/pudl0009/1/0...
# 4  http://diglib.princeton.edu/mdata/pudl0009/1/0...
#
#                                                Title  \
# 0  Patton Hall, Princeton University, Princeton, ...
# 1                  Patton Hall, Princeton University
# ...

# %%
selected_columns = df[['FilePath', 'OBJID', 'Title', 'Subtitles', 'Publishers', 'CopyrightDate', 'DateOther', 'Abstract', 'AATTopics', 'LCSHGeographics', 'LCSHNameParts', 'ImagePaths']]

# Now 'selected_columns' is a DataFrame containing only the selected columns. You can view it with:
selected_columns.head()
# Out:
#                                             FilePath                 OBJID  \
# 0  /content/drive/My Drive/AC045/AC045_c0055/0001...  ark:/88435/3f4625544
# 1  /content/drive/My Drive/AC045/AC045_c0055/0004...  ark:/88435/sb3978362
# 2  /content/drive/My Drive/AC045/AC045_c0028/0001...  ark:/88435/h128nd82h
# 3  /content/drive/My Drive/AC045/AC045_c0069/0003...  ark:/88435/r781wg134
# 4  /content/drive/My Drive/AC045/AC045_c0069/0002...  ark:/88435/gx41mh96w
#
#                                                Title  \
# 0  Patton Hall, Princeton University, Princeton, ...
# 1                  Patton Hall, Princeton University
# 2                     Elm Club, Princeton University
# 3                  University Place, Princeton, N.J.
# 4                  University Place, Princeton, N.J.
#
#                                     Subtitles  \
# 0  ['Series 1', 'Buildings, circa 1900-1960']
# 1  ['Series 1', 'Buildings, circa 1900-1960']
# 2  ['Series 1', 'Buildings, circa 1900-1960']
# ...

# %%
# !pip install --upgrade google-auth-httplib2 google-auth-oauthlib google-auth google-api-python-client oauthlib

# Define a function to create a thumbnail
def create_thumbnail(image_paths):
    for image_path in image_paths:
        with Image.open(image_path) as img:
            img.thumbnail((128, 128))  # Specify the size of the thumbnail
            # Save the thumbnail in the same directory with a '_thumbnail' suffix
            img.save(os.path.splitext(image_path)[0] + '_thumbnail' + os.path.splitext(image_path)[1])

# Apply the function to each list of image paths in the DataFrame
df['ImagePaths'].apply(create_thumbnail)
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 189.2/189.2 kB 6.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 45.4 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.9/96.9 kB 8.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.3/138.3 kB 19.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.8/48.8 kB 3.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 229.1/229.1 kB 23.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: google-auth
#     Found existing installation: google-auth 2.19.0
#     Uninstalling google-auth-2.19.0:
#       Successfully uninstalled google-auth-2.19.0
#   Attempting uninstall: google-auth-oauthlib
#     Found existing installation: google-auth-oauthlib 1.0.0
#     Uninstalling google-auth-oauthlib-1.0.0:
#       Successfully uninstalled google-auth-oauthlib-1.0.0
# ...
# ---------------------------------------------------------------------------
# ...
